# %%
from facebook_scraper import get_posts
import couchdb
import json
import time

# %%
couch= couchdb.Server('http://admin:Liz1234.@127.0.0.1:5984')
db=couch.create('noticias-mundiales')
db=couch['noticias-mundiales']

# %%
i=1
#for post in get_posts('liberaldelsuroficial', pages=1000, extra_info=True):
#for post in get_posts('elcomerciocom', pages=1000, extra_info=True):
#for post in get_posts('eluniversoec', pages=1000, extra_info=True):
#for post in get_posts('ElUniversalOnline', pages=1000, extra_info=True):
#for post in get_posts('eltiempo', pages=1000, extra_info=True):
for post in get_posts('lpg.laprensagrafica', pages=1000, extra_info=True):
    print(i)
    i=i+1
    time.sleep(5)
    
    id=post['post_id']
    doc={}
     
    collection['id']=id
    
    mydate=post['time']
    
    try:
        doc['texto']=post['text']
        doc['date']=mydate.timestamp()
        doc['likes']=post['likes']
        doc['comments']=post['comments']
        doc['shares']=post['shares']
        try:
            doc['reactions']=post['reactions']
        except:
            doc['reactions']={}

        doc['post_url']=post['post_url']
        db.save(doc)

    
        print("guardado exitosamente")

    except Exception as e:    
        print("no se pudo grabar:" + str(e))
# Out:
# 1
# guardado exitosamente
# 2
# guardado exitosamente
# 3
# guardado exitosamente
# 4
# guardado exitosamente
# 5
# guardado exitosamente
# 6
# guardado exitosamente
# 7
# guardado exitosamente
# 8
# guardado exitosamente
# 9
# guardado exitosamente
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# ...
